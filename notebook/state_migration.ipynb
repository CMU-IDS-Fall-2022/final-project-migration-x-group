# %%
import pandas as pd

# %%
state_migration = pd.read_csv("../data/state_migration.csv")
state_migration
# Out:
#       Unnamed: 0 o_state_name   d_state_name       n
# 0              0      Alabama        Alabama  399099
# 1              1      Alabama         Alaska     418
# 2              2      Alabama        Arizona     949
# 3              3      Alabama       Arkansas     913
# 4              4      Alabama     California    4154
# ...          ...          ...            ...     ...
# 2596        2596      Wyoming       Virginia     189
# 2597        2597      Wyoming     Washington    1138
# 2598        2598      Wyoming  West Virginia      33
# 2599        2599      Wyoming      Wisconsin     186
# 2600        2600      Wyoming        Wyoming   41806
#
# [2601 rows x 4 columns]

# %% [markdown]
# Group by origin state
# calculate the sum of n

# %%
o_state_groups = state_migration.groupby("o_state_name")

# %%
o_state_groups.get_group("Alabama")
# Out:
#     Unnamed: 0 o_state_name    d_state_name       n
# 0            0      Alabama         Alabama  399099
# 1            1      Alabama          Alaska     418
# 2            2      Alabama         Arizona     949
# 3            3      Alabama        Arkansas     913
# 4            4      Alabama      California    4154
# 5            5      Alabama        Colorado    2113
# 6            6      Alabama     Connecticut     307
# 7            7      Alabama              DC    1875
# 8            8      Alabama        Delaware     143
# 9            9      Alabama         Florida   11129
# 10          10      Alabama         Georgia   18778
# 11          11      Alabama          Hawaii     548
# 12          12      Alabama           Idaho     146
# 13          13      Alabama        Illinois    1574
# 14          14      Alabama         Indiana    1157
# 15          15      Alabama            Iowa     271
# 16          16      Alabama          Kansas     504
# ...

# %%
filtered_data = o_state_groups.get_group("Alabama")
filtered_data["%_of_total"] = (filtered_data["n"] / filtered_data["n"].sum()) * 100
filtered_data
# Out:
# /var/folders/91/27xg0jcj2dq9rv01tz61gk9r0000gq/T/ipykernel_16381/327804807.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data["%_of_total"] = (filtered_data["n"] / filtered_data["n"].sum()) * 100
#     Unnamed: 0 o_state_name    d_state_name       n  %_of_total
# 0            0      Alabama         Alabama  399099   80.434967
# 1            1      Alabama          Alaska     418    0.084244
# 2            2      Alabama         Arizona     949    0.191263
# 3            3      Alabama        Arkansas     913    0.184007
# 4            4      Alabama      California    4154    0.837203
# 5            5      Alabama        Colorado    2113    0.425857
# 6            6      Alabama     Connecticut     307    0.061873
# ...
