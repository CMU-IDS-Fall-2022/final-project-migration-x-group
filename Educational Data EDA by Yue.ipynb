# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline
import re

# %%
df = pd.read_csv('/Users/yuesun/Downloads/ACSDT1Y2021.B14001-2022-11-08T013154.csv', encoding='utf-8')

# %%
df
# Out:
#                                    Label (Grouping)  \
# 0                                            Total:
# 1                               Enrolled in school:
# 2             Enrolled in nursery school, preschool
# 3                          Enrolled in kindergarten
# 4                    Enrolled in grade 1 to grade 4
# 5                    Enrolled in grade 5 to grade 8
# 6                   Enrolled in grade 9 to grade 12
# 7          Enrolled in college, undergraduate years
# 8                   Graduate or professional school
# 9                            Not enrolled in school
#
#   Baldwin County, Alabama!!Estimate Calhoun County, Alabama!!Estimate  \
# 0                           233,161                           112,533
# 1                            44,235                            25,844
# 2                             2,308                             1,332
# 3                             2,906                             1,063
# ...

# %%
# swap x and y

# %%
df = df.swapaxes("index", "columns")
df
# Out:
#                                                       0  \
# Label (Grouping)                                 Total:
# Baldwin County, Alabama!!Estimate               233,161
# Calhoun County, Alabama!!Estimate               112,533
# Cullman County, Alabama!!Estimate                86,684
# DeKalb County, Alabama!!Estimate                 68,392
# ...                                                 ...
# Ponce Municipio, Puerto Rico!!Estimate          132,804
# San Juan Municipio, Puerto Rico!!Estimate       331,487
# Toa Alta Municipio, Puerto Rico!!Estimate        66,852
# Toa Baja Municipio, Puerto Rico!!Estimate        73,075
# Trujillo Alto Municipio, Puerto Rico!!Estimate   66,356
#
#                                                                       1  \
# Label (Grouping)                                    Enrolled in school:
# Baldwin County, Alabama!!Estimate                                44,235
# Calhoun County, Alabama!!Estimate                                25,844
# ...

# %%
# fix the header

# %%
df = df.rename(columns=df.iloc[0]).drop(df.index[0])
df
# Out:
#                                                  Total:  \
# Baldwin County, Alabama!!Estimate               233,161
# Calhoun County, Alabama!!Estimate               112,533
# Cullman County, Alabama!!Estimate                86,684
# DeKalb County, Alabama!!Estimate                 68,392
# Elmore County, Alabama!!Estimate                 87,103
# ...                                                 ...
# Ponce Municipio, Puerto Rico!!Estimate          132,804
# San Juan Municipio, Puerto Rico!!Estimate       331,487
# Toa Alta Municipio, Puerto Rico!!Estimate        66,852
# Toa Baja Municipio, Puerto Rico!!Estimate        73,075
# Trujillo Alto Municipio, Puerto Rico!!Estimate   66,356
#
#                                                    Enrolled in school:  \
# Baldwin County, Alabama!!Estimate                               44,235
# Calhoun County, Alabama!!Estimate                               25,844
# Cullman County, Alabama!!Estimate                               19,976
# ...

# %%
df.isnull().sum()
# Out:
# Total:                                              0
#     Enrolled in school:                             0
#         Enrolled in nursery school, preschool       0
#         Enrolled in kindergarten                    0
#         Enrolled in grade 1 to grade 4              0
#         Enrolled in grade 5 to grade 8              0
#         Enrolled in grade 9 to grade 12             0
#         Enrolled in college, undergraduate years    0
#         Graduate or professional school             0
#     Not enrolled in school                          0
# dtype: int64

# %%
# fix the index

# %%
df = df.reset_index()
df
# Out:
#                                               index   Total:  \
# 0                 Baldwin County, Alabama!!Estimate  233,161
# 1                 Calhoun County, Alabama!!Estimate  112,533
# 2                 Cullman County, Alabama!!Estimate   86,684
# 3                  DeKalb County, Alabama!!Estimate   68,392
# 4                  Elmore County, Alabama!!Estimate   87,103
# ..                                              ...      ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132,804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331,487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66,852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73,075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66,356
#
#         Enrolled in school:         Enrolled in nursery school, preschool  \
# 0                    44,235                                         2,308
# 1                    25,844                                         1,332
# ...

# %%
# fix the formating of the header

# %%
df = df.set_axis(['Label', 'Total', 'Enrolled in school', 'Enrolled in nursery school, preschool', 'Enrolled in kindergarten', 'Enrolled in grade 1 to 4', 'Enrolled in grade 5 to 8', 'Enrolled in grade 9 to 12', 'Enrolled in college, undergraduate years', 'Graduate or professional school', 'Not enrolled in school'], axis=1, inplace=False)
df
# Out:
#                                               Label    Total  \
# 0                 Baldwin County, Alabama!!Estimate  233,161
# 1                 Calhoun County, Alabama!!Estimate  112,533
# 2                 Cullman County, Alabama!!Estimate   86,684
# 3                  DeKalb County, Alabama!!Estimate   68,392
# 4                  Elmore County, Alabama!!Estimate   87,103
# ..                                              ...      ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132,804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331,487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66,852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73,075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66,356
#
#     Enrolled in school Enrolled in nursery school, preschool  \
# 0               44,235                                 2,308
# 1               25,844                                 1,332
# ...

# %%
# get rid of the "," in numbers and convert them from str to int

# %%
df['Total'] = df.Total.str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#     Enrolled in school Enrolled in nursery school, preschool  \
# 0               44,235                                 2,308
# 1               25,844                                 1,332
# ...

# %%
df['Enrolled in school'] = df['Enrolled in school'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school Enrolled in nursery school, preschool  \
# 0                 44235                                 2,308
# 1                 25844                                 1,332
# ...

# %%
df['Enrolled in nursery school, preschool'] = df['Enrolled in nursery school, preschool'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Enrolled in kindergarten'] = df['Enrolled in kindergarten'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Enrolled in grade 1 to 4'] = df['Enrolled in grade 1 to 4'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Enrolled in grade 5 to 8'] = df['Enrolled in grade 5 to 8'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Enrolled in grade 9 to 12'] = df['Enrolled in grade 9 to 12'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Enrolled in college, undergraduate years'] = df['Enrolled in college, undergraduate years'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Graduate or professional school'] = df['Graduate or professional school'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Not enrolled in school'] = df['Not enrolled in school'].str.split(',').str.join('').astype(int)
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
# add a Educational rate column

# %%
df['Educational ratio'] = (df['Enrolled in school'] / df['Total'])

# %%
df
# Out:
#                                               Label   Total  \
# 0                 Baldwin County, Alabama!!Estimate  233161
# 1                 Calhoun County, Alabama!!Estimate  112533
# 2                 Cullman County, Alabama!!Estimate   86684
# 3                  DeKalb County, Alabama!!Estimate   68392
# 4                  Elmore County, Alabama!!Estimate   87103
# ..                                              ...     ...
# 836          Ponce Municipio, Puerto Rico!!Estimate  132804
# 837       San Juan Municipio, Puerto Rico!!Estimate  331487
# 838       Toa Alta Municipio, Puerto Rico!!Estimate   66852
# 839       Toa Baja Municipio, Puerto Rico!!Estimate   73075
# 840  Trujillo Alto Municipio, Puerto Rico!!Estimate   66356
#
#      Enrolled in school  Enrolled in nursery school, preschool  \
# 0                 44235                                   2308
# 1                 25844                                   1332
# ...

# %%
df['Label'] = df['Label'].str.replace(r'!!Estimate$', '')
df
# Out:
# /var/folders/jb/y1fhlj6s7216bx8xsqnjjj9m0000gn/T/ipykernel_97464/246700172.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Label'] = df['Label'].str.replace(r'!!Estimate$', '')
#                                     Label   Total  Enrolled in school  \
# 0                 Baldwin County, Alabama  233161               44235
# 1                 Calhoun County, Alabama  112533               25844
# 2                 Cullman County, Alabama   86684               19976
# 3                  DeKalb County, Alabama   68392               15220
# 4                  Elmore County, Alabama   87103               20974
# ..                                    ...     ...                 ...
# 836          Ponce Municipio, Puerto Rico  132804               31034
# 837       San Juan Municipio, Puerto Rico  331487               75296
# 838       Toa Alta Municipio, Puerto Rico   66852               14596
# ...

# %%
df.to_csv('EducationByCZ.csv')
