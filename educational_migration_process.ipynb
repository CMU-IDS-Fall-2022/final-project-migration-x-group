# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/state_migration_summary.csv")

# %%
df2 = pd.read_csv("data/Educational_By_State.csv")
#df2['state'] = df2['state'].str.upper()

# %%
df = df2.merge(df1, on='state', how='inner')[['state', 'average', 'inbound_migration']]

# %%
df
# Out:
#              state   average  inbound_migration
# 0          Alabama  0.137769              84839
# 1           Alaska  0.155198              34415
# 2          Arizona  0.141589             183771
# 3         Arkansas  0.148254              62441
# 4       California  0.151790             504576
# 5         Colorado  0.149435             245699
# 6      Connecticut  0.141736              55843
# 7         Delaware  0.134336              30891
# 8          Florida  0.122612             410194
# 9          Georgia  0.158508             261915
# 10          Hawaii  0.122965              47822
# 11           Idaho  0.154907              43132
# 12        Illinois  0.149698             206324
# 13         Indiana  0.148401             112518
# 14            Iowa  0.164677              56150
# 15          Kansas  0.167616              54225
# 16        Kentucky  0.146538              80037
# 17       Louisiana  0.143493              83579
# 18           Maine  0.125722              20980
# 19        Maryland  0.146540              84969
# 20   Massachusetts  0.140612             153343
# 21        Michigan  0.145278              86484
# 22       Minnesota  0.155147              97204
# 23     Mississippi  0.151209              45371
# 24        Missouri  0.144555             146361
# 25         Montana  0.135098              35338
# 26        Nebraska  0.164897              44186
# 27          Nevada  0.138507             113948
# 28   New Hampshire  0.136966              37892
# 29      New Jersey  0.138541              87274
# 30      New Mexico  0.150929              49046
# 31        New York  0.138762             361930
# 32  North Carolina  0.137602             281471
# 33    North Dakota  0.150886              39400
# 34            Ohio  0.137804             144809
# 35        Oklahoma  0.154387              90925
# 36          Oregon  0.136939             129663
# 37    Pennsylvania  0.127580             203766
# 38    Rhode Island  0.134250              31811
# 39  South Carolina  0.139246             114786
# 40    South Dakota  0.139479              25344
# 41       Tennessee  0.137023             191617
# 42           Texas  0.155736             467209
# 43            Utah  0.189315              92424
# 44         Vermont  0.157409              20318
# 45        Virginia  0.148161             170677
# 46      Washington  0.135134             204326
# 47   West Virginia  0.134669              24599
# 48       Wisconsin  0.142197              89055
# 49         Wyoming  0.138854              27337

# %%
df.to_csv('data/Educational_Migration.csv')
