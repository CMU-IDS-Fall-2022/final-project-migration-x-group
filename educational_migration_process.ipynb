# %%
import pandas as pd

# %%
df1 = pd.read_csv("data/state_migration_summary.csv")

# %%
df2 = pd.read_csv("data/EducationalByState.csv")
#df2['state'] = df2['state'].str.upper()

# %%
df = df2.merge(df1, on='state', how='inner')[['state', 'average', 'inbound_migration_rate']]

# %%
df
# Out:
#              state   average  inbound_migration_rate
# 0          Alabama  0.137769                0.146019
# 1           Alaska  0.155198                0.289545
# 2          Arizona  0.141589                0.251125
# 3         Arkansas  0.148254                0.160710
# 4       California  0.151790                0.123318
# 5         Colorado  0.149435                0.342447
# 6      Connecticut  0.141736                0.130353
# 7         Delaware  0.134336                0.205537
# 8          Florida  0.122612                0.199121
# 9          Georgia  0.158508                0.203709
# 10          Hawaii  0.122965                0.285557
# 11           Idaho  0.154907                0.237883
# 12        Illinois  0.149698                0.133220
# 13         Indiana  0.148401                0.130434
# 14            Iowa  0.164677                0.151169
# 15          Kansas  0.167616                0.186913
# 16        Kentucky  0.146538                0.157286
# ...

# %%
df.to_csv('data/Educational_Migration.csv')
