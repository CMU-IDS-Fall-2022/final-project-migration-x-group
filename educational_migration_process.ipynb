# %%
import pandas as pd

# %%
df1 = pd.read_csv("/Users/yuesun/Downloads/final-project-migration-x-group-main/data/state_migration_summary.csv")

# %%
df2 = pd.read_csv("/Users/yuesun/Desktop/Educational_By_State.csv")
df2['state'] = df2['state'].str.upper()

# %%
df = df2.merge(df1, on='state', how='inner')[['state', 'average', 'inbound_migration']]

# %%
df
# Out:
#                    state   average  inbound_migration
# 0                ALABAMA  0.137769              99862
# 1                 ALASKA  0.155198              32915
# 2                ARIZONA  0.141589             238284
# 3               ARKANSAS  0.148254              57806
# 4             CALIFORNIA  0.151790             450816
# 5               COLORADO  0.149435             236936
# 6            CONNECTICUT  0.141736              85779
# 7               DELAWARE  0.134336              31838
# 8   DISTRICT OF COLUMBIA  0.140557              53582
# 9                FLORIDA  0.122612             535474
# 10               GEORGIA  0.158508             258249
# 11                HAWAII  0.122965              46870
# 12                 IDAHO  0.154907              75943
# 13              ILLINOIS  0.149698             190531
# 14               INDIANA  0.148401             145727
# 15                  IOWA  0.164677              68176
# ...

# %%
df.to_csv('Educational_Migration.csv')
